# %% [markdown]
# # COVID-19 prediction

# %% [markdown]
# ## Import data and packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Data_cleaned/covid.csv')

# %%
df.head()
# Out:
#   state        date  critical_staffing_shortage_today_yes  \
# 0    ME  2021/01/20                                     3
# 1    SD  2021/01/20                                     2
# 2    MS  2021/01/17                                    12
# 3    CT  2021/01/13                                     4
# 4    MT  2021/01/13                                    10
#
#    critical_staffing_shortage_today_no  \
# 0                                   28
# 1                                   60
# 2                                   95
# 3                                   35
# 4                                   56
#
#    critical_staffing_shortage_today_not_reported  \
# 0                                              8
# 1                                              3
# 2                                              2
# 3                                              1
# 4                                              1
#
#    critical_staffing_shortage_anticipated_within_week_yes  \
# 0                                                  2
# 1                                                  2
# 2                                                 16
# 3                                                  4
# 4                                                 11
#
#    critical_staffing_shortage_anticipated_within_week_no  \
# 0                                                 29
# 1                                                 60
# 2                                                 91
# 3                                                 35
# 4                                                 55
#
#    critical_staffing_shortage_anticipated_within_week_not_reported  \
# 0                                                  8
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    hospital_onset_covid  hospital_onset_covid_coverage  ...  \
# 0                   7.0                             38  ...
# 1                  34.0                             62  ...
# 2                  10.0                            107  ...
# 3                  31.0                             39  ...
# 4                  18.0                             66  ...
#
#    previous_day_admission_pediatric_covid_confirmed_5_11  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    previous_day_admission_pediatric_covid_confirmed_5_11_coverage  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    previous_day_admission_pediatric_covid_confirmed_unknown  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    previous_day_admission_pediatric_covid_confirmed_unknown_coverage  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    staffed_icu_pediatric_patients_confirmed_covid  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    staffed_icu_pediatric_patients_confirmed_covid_coverage  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    staffed_pediatric_icu_bed_occupancy  \
# 0                                 47.0
# 1                                 33.0
# 2                                 78.0
# 3                                196.0
# 4                                 12.0
#
#    staffed_pediatric_icu_bed_occupancy_coverage  \
# 0                                            38
# 1                                            62
# 2                                           107
# 3                                            39
# 4                                            21
#
#    total_staffed_pediatric_icu_beds  total_staffed_pediatric_icu_beds_coverage
# 0                              54.0                                         38
# 1                              83.0                                         62
# 2                             180.0                                        107
# 3                             335.0                                         39
# 4                              40.0                                         21
#
# [5 rows x 135 columns]

# %% [markdown]
# ## Initial EDA

# %%
# number of rows and columns
df.shape
# Out:
# (52445, 135)

# %% [markdown]
# ### Lets filter out some features

# %% [markdown]
# Lets better understand the data types in our dataset

# %%
# how many columns per data type
df.dtypes.value_counts()
# Out:
# float64    77
# int64      56
# object      2
# dtype: int64

# %% [markdown]
# What are our object columns exactly

# %%
# print object columns
df.select_dtypes('object').columns
# Out:
# Index(['state', 'date'], dtype='object')

# %% [markdown]
# #### We can convert 'state' to string and 'date' to a time stamp

# %%
# convert date column to datetime
df['date'] = pd.to_datetime(df['date'])

# convert state column to string 
df['state'] = df['state'].astype(str)

# %% [markdown]
# #### Normalize "therapeutics" by beds_used_coverage

# %%
# divide all columns with "therapeutics" in the name by the "beds_coverage" column
cols_thera = [col for col in df.columns if 'therapeutic' in col]
for col in cols_thera:
    df[col] = df[col]/df['inpatient_beds_coverage']

# %% [markdown]
# #### Normalize columns by their relative counterpart

# %%
# find all column names pairs of ("col", "col_coverage")
cols_coverage = [col for col in df.columns if 'coverage' in col]

# col reg as cols_coverage without "_coverage"
cols_reg = [col.replace('_coverage', '') for col in cols_coverage]

# %%
for i in range(len(cols_reg)):
    df[cols_reg[i]] = df[cols_reg[i]]/df[cols_coverage[i]]

# %% [markdown]
# #### Remove utilization cols

# %%
# cols that have "numerator" in the name but not "numerator" or "denominator"
cols_utilization = [col for col in df.columns if 'utilization' in col and 'numerator' not in col and 'denominator' not in col]

# %%
# drop cols_utilization
df.drop(cols_utilization, axis=1, inplace=True)

# %% [markdown]
# #### Remove geocoded_state

# %%
# drop "geocode_state"
df.drop('geocoded_state', axis=1, inplace=True)

# %% [markdown]
# #### Remove columns which have a majority of Nan

# %%
def nan_cols(df, pct):
    """function to return columns with more than pct % of missing values"""
    lst = df.columns[df.isnull().mean() > pct]
    return lst

# %%
# columns with more than 50% of missing values
nan50 = nan_cols(df, 0.5)

# drop columns with more than 50% of missing values
df.drop(nan50, axis=1, inplace=True)

# %% [markdown]
# #### Removing data related to influenza as we are working specifically on this data

# %%
# how many column names with "influenza" in it
influenza = df.columns[df.columns.str.contains('influenza')].tolist()
influenza
# Out:
# ['icu_patients_confirmed_influenza',
#  'icu_patients_confirmed_influenza_coverage',
#  'previous_day_admission_influenza_confirmed',
#  'previous_day_admission_influenza_confirmed_coverage',
#  'previous_day_deaths_covid_and_influenza',
#  'previous_day_deaths_covid_and_influenza_coverage',
#  'previous_day_deaths_influenza',
#  'previous_day_deaths_influenza_coverage',
#  'total_patients_hospitalized_confirmed_influenza',
#  'total_patients_hospitalized_confirmed_influenza_and_covid',
#  'total_patients_hospitalized_confirmed_influenza_and_covid_coverage',
#  'total_patients_hospitalized_confirmed_influenza_coverage']

# %%
# drop influenza columns
df.drop(influenza, axis=1, inplace=True)

# %% [markdown]
# #### Remove the columns with "coverage"

# %%
# create a df wihtout columns that have "coverage" in it
df = df[df.columns[~df.columns.str.contains('coverage')]]

# %%
# print lal variables with correlation >0.8 but not equal to 1
corr = df.corr()
# pairs above 0.7
pairs = corr[corr > 0.95][corr != 1].stack().reset_index().sort_values(by=0, ascending=False)
pairs
# Out:
#                                               level_0  \
# 50              adult_icu_bed_utilization_denominator
# 39        adult_icu_bed_covid_utilization_denominator
# 20         percent_of_inpatients_with_covid_numerator
# 27          inpatient_bed_covid_utilization_numerator
# 29        inpatient_bed_covid_utilization_denominator
# 16             inpatient_beds_utilization_denominator
# 9                inpatient_beds_utilization_numerator
# 21       percent_of_inpatients_with_covid_denominator
# 14             inpatient_beds_utilization_denominator
# 8                inpatient_beds_utilization_numerator
# 30        inpatient_bed_covid_utilization_denominator
# 23       percent_of_inpatients_with_covid_denominator
# 22       percent_of_inpatients_with_covid_denominator
# 15             inpatient_beds_utilization_denominator
# 10               inpatient_beds_utilization_numerator
# 28        inpatient_bed_covid_utilization_denominator
# 7   total_adult_patients_hospitalized_confirmed_covid
# 6   total_adult_patients_hospitalized_confirmed_an...
# 45                adult_icu_bed_utilization_numerator
# 51              adult_icu_bed_utilization_denominator
# 44                adult_icu_bed_utilization_numerator
# 38        adult_icu_bed_covid_utilization_denominator
# 4          staffed_icu_adult_patients_confirmed_covid
# 3   staffed_icu_adult_patients_confirmed_and_suspe...
# 19             inpatient_beds_utilization_denominator
# 47              adult_icu_bed_utilization_denominator
# 17             inpatient_beds_utilization_denominator
# 35        adult_icu_bed_covid_utilization_denominator
# 49              adult_icu_bed_utilization_denominator
# 33        inpatient_bed_covid_utilization_denominator
# 37        adult_icu_bed_covid_utilization_denominator
# 31        inpatient_bed_covid_utilization_denominator
# 46              adult_icu_bed_utilization_denominator
# 13               inpatient_beds_utilization_numerator
# 11               inpatient_beds_utilization_numerator
# 34        adult_icu_bed_covid_utilization_denominator
# 48              adult_icu_bed_utilization_denominator
# 26       percent_of_inpatients_with_covid_denominator
# 36        adult_icu_bed_covid_utilization_denominator
# 24       percent_of_inpatients_with_covid_denominator
# 40                adult_icu_bed_utilization_numerator
# 12               inpatient_beds_utilization_numerator
# 42                adult_icu_bed_utilization_numerator
# 25       percent_of_inpatients_with_covid_denominator
# 41                adult_icu_bed_utilization_numerator
# 18             inpatient_beds_utilization_denominator
# 32        inpatient_bed_covid_utilization_denominator
# 43                adult_icu_bed_utilization_numerator
# 5   total_adult_patients_hospitalized_confirmed_an...
# 2                           inpatient_beds_used_covid
# 1                                 inpatient_beds_used
# 0                                      inpatient_beds
#
#                                               level_1         0
# 50        adult_icu_bed_covid_utilization_denominator  0.999836
# 39              adult_icu_bed_utilization_denominator  0.999836
# 20          inpatient_bed_covid_utilization_numerator  0.999758
# 27         percent_of_inpatients_with_covid_numerator  0.999758
# 29             inpatient_beds_utilization_denominator  0.999106
# 16        inpatient_bed_covid_utilization_denominator  0.999106
# 9        percent_of_inpatients_with_covid_denominator  0.999066
# 21               inpatient_beds_utilization_numerator  0.999066
# 14               inpatient_beds_utilization_numerator  0.992918
# 8              inpatient_beds_utilization_denominator  0.992918
# 30       percent_of_inpatients_with_covid_denominator  0.992430
# 23        inpatient_bed_covid_utilization_denominator  0.992430
# 22             inpatient_beds_utilization_denominator  0.992419
# 15       percent_of_inpatients_with_covid_denominator  0.992419
# 10        inpatient_bed_covid_utilization_denominator  0.991519
# 28               inpatient_beds_utilization_numerator  0.991519
# 7   total_adult_patients_hospitalized_confirmed_an...  0.988783
# 6   total_adult_patients_hospitalized_confirmed_covid  0.988783
# 45              adult_icu_bed_utilization_denominator  0.984196
# 51                adult_icu_bed_utilization_numerator  0.984196
# 44        adult_icu_bed_covid_utilization_denominator  0.983471
# 38                adult_icu_bed_utilization_numerator  0.983471
# 4   staffed_icu_adult_patients_confirmed_and_suspe...  0.983426
# 3          staffed_icu_adult_patients_confirmed_covid  0.983426
# 19              adult_icu_bed_utilization_denominator  0.981989
# 47             inpatient_beds_utilization_denominator  0.981989
# 17        adult_icu_bed_covid_utilization_denominator  0.981670
# 35             inpatient_beds_utilization_denominator  0.981670
# 49        inpatient_bed_covid_utilization_denominator  0.981442
# 33              adult_icu_bed_utilization_denominator  0.981442
# 37        inpatient_bed_covid_utilization_denominator  0.981178
# 31        adult_icu_bed_covid_utilization_denominator  0.981178
# 46               inpatient_beds_utilization_numerator  0.980012
# 13              adult_icu_bed_utilization_denominator  0.980012
# 11        adult_icu_bed_covid_utilization_denominator  0.979583
# 34               inpatient_beds_utilization_numerator  0.979583
# 48       percent_of_inpatients_with_covid_denominator  0.979534
# 26              adult_icu_bed_utilization_denominator  0.979534
# 36       percent_of_inpatients_with_covid_denominator  0.979140
# 24        adult_icu_bed_covid_utilization_denominator  0.979140
# 40               inpatient_beds_utilization_numerator  0.978958
# 12                adult_icu_bed_utilization_numerator  0.978958
# 42       percent_of_inpatients_with_covid_denominator  0.977903
# 25                adult_icu_bed_utilization_numerator  0.977903
# 41             inpatient_beds_utilization_denominator  0.973657
# 18                adult_icu_bed_utilization_numerator  0.973657
# 32                adult_icu_bed_utilization_numerator  0.972912
# 43        inpatient_bed_covid_utilization_denominator  0.972912
# 5                           inpatient_beds_used_covid  0.967690
# 2   total_adult_patients_hospitalized_confirmed_an...  0.967690
# 1                                      inpatient_beds  0.955349
# 0                                 inpatient_beds_used  0.955349

# %%
# how many unique variables in pairs
pairs['level_0'].nunique()
# Out:
# 16

# %% [markdown]
# #### Remove "pediatrics"

# %%
# remove columns with "pediatrics" in it
df.drop(df.columns[df.columns.str.contains('pediatrics')], axis=1, inplace=True)

# %% [markdown]
# Should we maybe do some sort of Holistic Regression or whatnot to reduce the number of variables ? or do it manually ? <br>
# Do we really want to keep pediatrics ?

# %% [markdown]
# #### Remove "states" that are actually territories

# %%
# drop rows with number of points per state < 900
df = df.groupby('state').filter(lambda x: len(x) > 900)

#  how many states in df
df['state'].nunique()
# Out:
# 53

# %%
# remove VI, PR and AS from df
df = df[~df['state'].isin(['VI', 'PR', 'AS'])]

#  how many states in df
df['state'].nunique()
# Out:
# 51

# %%
df.shape
# Out:
# (50088, 64)

# %%
df.head()
# Out:
#   state       date  critical_staffing_shortage_today_yes  \
# 0    ME 2021-01-20                                     3
# 1    SD 2021-01-20                                     2
# 2    MS 2021-01-17                                    12
# 3    CT 2021-01-13                                     4
# 4    MT 2021-01-13                                    10
#
#    critical_staffing_shortage_today_no  \
# 0                                   28
# 1                                   60
# 2                                   95
# 3                                   35
# 4                                   56
#
#    critical_staffing_shortage_today_not_reported  \
# 0                                              8
# 1                                              3
# 2                                              2
# 3                                              1
# 4                                              1
#
#    critical_staffing_shortage_anticipated_within_week_yes  \
# 0                                                  2
# 1                                                  2
# 2                                                 16
# 3                                                  4
# 4                                                 11
#
#    critical_staffing_shortage_anticipated_within_week_no  \
# 0                                                 29
# 1                                                 60
# 2                                                 91
# 3                                                 35
# 4                                                 55
#
#    critical_staffing_shortage_anticipated_within_week_not_reported  \
# 0                                                  8
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    hospital_onset_covid  inpatient_beds  ...  \
# 0              0.184211       83.230769  ...
# 1              0.548387       43.953846  ...
# 2              0.093458       79.743119  ...
# 3              0.794872      211.275000  ...
# 4              0.272727       48.059701  ...
#
#    on_hand_supply_therapeutic_a_casirivimab_imdevimab_courses  \
# 0                                           4.461538
# 1                                           7.984615
# 2                                           3.266055
# 3                                          40.625000
# 4                                          24.552239
#
#    on_hand_supply_therapeutic_b_bamlanivimab_courses  \
# 0                                           8.897436
# 1                                          14.061538
# 2                                          24.477064
# 3                                          86.075000
# 4                                           7.014925
#
#    on_hand_supply_therapeutic_c_bamlanivimab_etesevimab_courses  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    previous_week_therapeutic_a_casirivimab_imdevimab_courses_used  \
# 0                                           0.025641
# 1                                           0.338462
# 2                                           0.917431
# 3                                           0.250000
# 4                                           1.940299
#
#    previous_week_therapeutic_b_bamlanivimab_courses_used  \
# 0                                           1.384615
# 1                                           3.753846
# 2                                          13.889908
# 3                                           4.850000
# 4                                          14.134328
#
#    previous_week_therapeutic_c_bamlanivimab_etesevimab_courses_used  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    all_pediatric_inpatient_bed_occupied  all_pediatric_inpatient_beds  \
# 0                              4.394737                      5.789474
# 1                              4.790323                      5.854839
# 2                              3.224299                     22.925234
# 3                             11.641026                     17.564103
# 4                              3.380952                      7.761905
#
#    staffed_pediatric_icu_bed_occupancy  total_staffed_pediatric_icu_beds
# 0                             1.236842                          1.421053
# 1                             0.532258                          1.338710
# 2                             0.728972                          1.682243
# 3                             5.025641                          8.589744
# 4                             0.571429                          1.904762
#
# [5 rows x 64 columns]

# %% [markdown]
# ## Remove columns with still too many NaNs

# %%
# number of Nan values in each column as a dataframe
df.isna().sum().to_frame().sort_values(by=0, ascending=False).head(10)
# Out:
#                                                         0
# on_hand_supply_therapeutic_c_bamlanivimab_etese...  19640
# previous_week_therapeutic_c_bamlanivimab_etesev...  19623
# on_hand_supply_therapeutic_b_bamlanivimab_courses   15321
# previous_week_therapeutic_b_bamlanivimab_course...  15285
# on_hand_supply_therapeutic_a_casirivimab_imdevi...  15088
# previous_week_therapeutic_a_casirivimab_imdevim...  15087
# total_staffed_pediatric_icu_beds                     7768
# all_pediatric_inpatient_beds                         7764
# staffed_pediatric_icu_bed_occupancy                  7756
# all_pediatric_inpatient_bed_occupied                 7752

# %% [markdown]
# We can remove all the columns with therapeutic as they have more than 15,000 NaN

# %%
# print columns with "therapeutic" in column name
therapeutic = df.columns[df.columns.str.contains('therapeutic')].tolist()
therapeutic
# Out:
# ['on_hand_supply_therapeutic_a_casirivimab_imdevimab_courses',
#  'on_hand_supply_therapeutic_b_bamlanivimab_courses',
#  'on_hand_supply_therapeutic_c_bamlanivimab_etesevimab_courses',
#  'previous_week_therapeutic_a_casirivimab_imdevimab_courses_used',
#  'previous_week_therapeutic_b_bamlanivimab_courses_used',
#  'previous_week_therapeutic_c_bamlanivimab_etesevimab_courses_used']

# %%
# drop columns with "therapeutic" in column name
df.drop(therapeutic, axis=1, inplace=True)

# %% [markdown]
# #### Drop all values for dates that do not have all states

# %%
# how many unique states per date
# increase plot size
plt.figure(figsize=(10,5))
df.groupby('date')['state'].nunique().plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# which date are there less than 50 states
df.groupby('date')['state'].nunique().loc['2020-03-27']
# Out:
# 50

# %%
df.groupby('date')['state'].nunique().loc['2020-03-28']
# Out:
# 51

# %%
# drop values before 2020-03-28
df = df.loc['2020-03-28':]

# %%
df.head()
# Out:
#       state       date  critical_staffing_shortage_today_yes  \
# 20200    OR 2020-03-31                                     0
# 20201    IL 2022-09-18                                     6
# 20202    CO 2020-03-18                                     0
# 20203    NM 2020-03-15                                     0
# 20204    MT 2020-05-26                                     0
#
#        critical_staffing_shortage_today_no  \
# 20200                                    0
# 20201                                  152
# 20202                                    0
# 20203                                    0
# 20204                                    0
#
#        critical_staffing_shortage_today_not_reported  \
# 20200                                             12
# 20201                                             28
# 20202                                              2
# 20203                                              1
# 20204                                             68
#
#        critical_staffing_shortage_anticipated_within_week_yes  \
# 20200                                                  0
# 20201                                                 14
# 20202                                                  0
# 20203                                                  0
# 20204                                                  0
#
#        critical_staffing_shortage_anticipated_within_week_no  \
# 20200                                                  0
# 20201                                                147
# 20202                                                  0
# 20203                                                  0
# 20204                                                  0
#
#        critical_staffing_shortage_anticipated_within_week_not_reported  \
# 20200                                                 12
# 20201                                                 25
# 20202                                                  2
# 20203                                                  1
# 20204                                                 68
#
#        hospital_onset_covid  inpatient_beds  ...  \
# 20200              0.000000      104.500000  ...
# 20201              0.132597      149.844086  ...
# 20202              0.000000        8.500000  ...
# 20203                   NaN       22.000000  ...
# 20204              0.000000       37.955882  ...
#
#        previous_day_admission_adult_covid_suspected_50-59  \
# 20200                                                NaN
# 20201                                           0.185897
# 20202                                                NaN
# 20203                                                NaN
# 20204                                                NaN
#
#        previous_day_admission_adult_covid_suspected_60-69  \
# 20200                                                NaN
# 20201                                           0.230769
# 20202                                                NaN
# 20203                                                NaN
# 20204                                                NaN
#
#        previous_day_admission_adult_covid_suspected_70-79  \
# 20200                                                NaN
# 20201                                           0.205128
# 20202                                                NaN
# 20203                                                NaN
# 20204                                                NaN
#
#        previous_day_admission_adult_covid_suspected_80+  \
# 20200                                               NaN
# 20201                                          0.217949
# 20202                                               NaN
# 20203                                               NaN
# 20204                                               NaN
#
#        previous_day_admission_adult_covid_suspected_unknown  deaths_covid  \
# 20200                                                NaN             0.00
# 20201                                                0.0             0.05
# 20202                                                NaN             0.00
# 20203                                                NaN              NaN
# 20204                                                NaN             0.00
#
#        all_pediatric_inpatient_bed_occupied  all_pediatric_inpatient_beds  \
# 20200                                   NaN                           NaN
# 20201                              5.071823                      7.359116
# 20202                                   NaN                           NaN
# 20203                                   NaN                           NaN
# 20204                                   NaN                           NaN
#
#        staffed_pediatric_icu_bed_occupancy  total_staffed_pediatric_icu_beds
# 20200                                  NaN                               NaN
# 20201                             2.044199                          3.248619
# 20202                                  NaN                               NaN
# 20203                                  NaN                               NaN
# 20204                                  NaN                               NaN
#
# [5 rows x 58 columns]

# %%
# output df to csv
df.to_csv('Data_cleaned/covid_clean.csv', index=False)

# %% [markdown]
# #### Drop percent column

# %%
# print columns with percent in name and not numerator or denominator
percent = df.columns[df.columns.str.contains('percent')].tolist()
percent
# Out:
# ['percent_of_inpatients_with_covid',
#  'percent_of_inpatients_with_covid_numerator',
#  'percent_of_inpatients_with_covid_denominator']

# %%
# drop first column of percent 
df.drop(percent[0], axis=1, inplace=True)

# %% [markdown]
# ## Data imputation

# %%
# use KNN imputer to fill missing values
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)

# %%
# df = pd.read_csv('covid_clean_imputted.csv')

# %%
# use KNN imputer to fill missing numeric values
df.iloc[:, 2:] = imputer.fit_transform(df.iloc[:, 2:])
# df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
#  number of Nan values in the df
df.isna().sum().sum()
# Out:
# 0

# %%
# KNN imputer for string values
# df['state'] = df['state'].fillna(df['state'].mode()[0])

# %%
# replace the row number with the date
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date')

# %%
#  sort the index by date in ascending order and then by country in descending order 
df = df.sort_index(ascending=True, axis=0)

# %%
# output df to csv
df.to_csv('Data_cleaned/covid_clean_imputted.csv', index=True)

# %% [markdown]
# ### Aggregate dataset by date

# %%
# group df by index 
df = df.groupby('date').sum()

# %%
df.shape
# Out:
# (820, 55)

# %% [markdown]
# #### Coverage for _yes, _no, _not_reported

# %%
#  variables with '_yes' in the name
cols_yes = [col for col in df.columns if '_yes' in col]
cols_nr = [col for col in df.columns if '_not_reported' in col]
cols_no = [col for col in df.columns if '_no' in col and col not in cols_nr]

for i in range(2):
    df[cols_yes[i]] = df[cols_yes[i]]/(df[cols_yes[i]] + df[cols_no[i]] + df[cols_nr[i]])
    df[cols_no[i]] = df[cols_no[i]]/(df[cols_yes[i]] + df[cols_no[i]] + df[cols_nr[i]])
    df[cols_nr[i]] = df[cols_nr[i]]/(df[cols_yes[i]] + df[cols_no[i]] + df[cols_nr[i]])

# %% [markdown]
# #### Utilization for num/denom

# %%
cols_num = [col for col in df.columns if '_numerator' in col]
cols_denom = [col for col in df.columns if '_denominator' in col]

# %%
# df[cols_num] = df[cols_num].div(df[cols_denom], axis=0)
for i in range(len(cols_num)):
    df[cols_num[i]] = df[cols_num[i]]/df[cols_denom[i]]

# %%
# drop cols_denom
df.drop(cols_denom, axis=1, inplace=True)

# %%
# replace "numerator" in column names with "utilization"
df.columns = df.columns.str.replace('numerator', 'utilization')

# %%
# export as csv
df.to_csv('Data_cleaned/covid_clean_imputted_aggregated.csv', index=True)

# %% [markdown]
# ### Imputted and standardized

# %%
# standardize df
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df.iloc[:, 1:] = scaler.fit_transform(df.iloc[:, 1:])

# %%
# export df to csv
df.to_csv('Data_cleaned/covid_clean_imputted_std_aggregated.csv', index=True)

# %% [markdown]
# ### Lets build a correlation plot of the variables in our model

# %%
corrM = df.corr()
corrM.style.background_gradient(cmap='coolwarm',axis=None).set_precision(2)
# Out:
# <style type="text/css">
# #T_99d64_row0_col0, #T_99d64_row1_col1, #T_99d64_row2_col2, #T_99d64_row2_col5, #T_99d64_row3_col3, #T_99d64_row4_col4, #T_99d64_row5_col2, #T_99d64_row5_col5, #T_99d64_row6_col6, #T_99d64_row7_col7, #T_99d64_row7_col8, #T_99d64_row8_col7, #T_99d64_row8_col8, #T_99d64_row9_col9, #T_99d64_row9_col17, #T_99d64_row9_col18, #T_99d64_row10_col10, #T_99d64_row10_col32, #T_99d64_row11_col11, #T_99d64_row12_col12, #T_99d64_row13_col13, #T_99d64_row14_col14, #T_99d64_row15_col15, #T_99d64_row15_col16, #T_99d64_row16_col15, #T_99d64_row16_col16, #T_99d64_row17_col9, #T_99d64_row17_col17, #T_99d64_row17_col18, #T_99d64_row18_col9, #T_99d64_row18_col17, #T_99d64_row18_col18, #T_99d64_row19_col19, #T_99d64_row20_col20, #T_99d64_row21_col21, #T_99d64_row22_col22, #T_99d64_row23_col23, #T_99d64_row24_col24, #T_99d64_row25_col25, #T_99d64_row26_col26, #T_99d64_row27_col27, #T_99d64_row28_col28, #T_99d64_row29_col29, #T_99d64_row30_col30, #T_99d64_row31_col31, #T_99d64_row32_col10, #T_99d64_row32_col32, #T_99d64_row33_col