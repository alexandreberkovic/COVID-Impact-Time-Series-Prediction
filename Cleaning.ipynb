# %% [markdown]
# # COVID-19 prediction

# %% [markdown]
# ## Import data and packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('covid.csv')

# %%
df.head()
# Out:
#   state        date  critical_staffing_shortage_today_yes  \
# 0    ME  2021/01/20                                     3
# 1    SD  2021/01/20                                     2
# 2    MS  2021/01/17                                    12
# 3    CT  2021/01/13                                     4
# 4    MT  2021/01/13                                    10
#
#    critical_staffing_shortage_today_no  \
# 0                                   28
# 1                                   60
# 2                                   95
# 3                                   35
# 4                                   56
#
#    critical_staffing_shortage_today_not_reported  \
# 0                                              8
# 1                                              3
# 2                                              2
# 3                                              1
# 4                                              1
#
#    critical_staffing_shortage_anticipated_within_week_yes  \
# 0                                                  2
# 1                                                  2
# 2                                                 16
# 3                                                  4
# 4                                                 11
#
#    critical_staffing_shortage_anticipated_within_week_no  \
# 0                                                 29
# 1                                                 60
# 2                                                 91
# 3                                                 35
# 4                                                 55
#
#    critical_staffing_shortage_anticipated_within_week_not_reported  \
# 0                                                  8
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    hospital_onset_covid  hospital_onset_covid_coverage  ...  \
# 0                   7.0                             38  ...
# 1                  34.0                             62  ...
# 2                  10.0                            107  ...
# 3                  31.0                             39  ...
# 4                  18.0                             66  ...
#
#    previous_day_admission_pediatric_covid_confirmed_5_11  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    previous_day_admission_pediatric_covid_confirmed_5_11_coverage  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    previous_day_admission_pediatric_covid_confirmed_unknown  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    previous_day_admission_pediatric_covid_confirmed_unknown_coverage  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    staffed_icu_pediatric_patients_confirmed_covid  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    staffed_icu_pediatric_patients_confirmed_covid_coverage  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    staffed_pediatric_icu_bed_occupancy  \
# 0                                 47.0
# 1                                 33.0
# 2                                 78.0
# 3                                196.0
# 4                                 12.0
#
#    staffed_pediatric_icu_bed_occupancy_coverage  \
# 0                                            38
# 1                                            62
# 2                                           107
# 3                                            39
# 4                                            21
#
#    total_staffed_pediatric_icu_beds  total_staffed_pediatric_icu_beds_coverage
# 0                              54.0                                         38
# 1                              83.0                                         62
# 2                             180.0                                        107
# 3                             335.0                                         39
# 4                              40.0                                         21
#
# [5 rows x 135 columns]

# %% [markdown]
# ## Initial EDA

# %%
# number of rows and columns
df.shape
# Out:
# (52445, 135)

# %% [markdown]
# ### Lets filter out some features

# %% [markdown]
# Lets better understand the data types in our dataset

# %%
# how many columns per data type
df.dtypes.value_counts()
# Out:
# float64    77
# int64      56
# object      2
# dtype: int64

# %% [markdown]
# What are our object columns exactly

# %%
# print object columns
df.select_dtypes('object').columns
# Out:
# Index(['state', 'date'], dtype='object')

# %% [markdown]
# #### We can convert 'state' to string and 'date' to a time stamp

# %%
# convert date column to datetime
df['date'] = pd.to_datetime(df['date'])

# convert state column to string 
df['state'] = df['state'].astype(str)

# %% [markdown]
# #### Remove columns which have a majority of Nan

# %%
def nan_cols(df, pct):
    """function to return columns with more than pct % of missing values"""
    lst = df.columns[df.isnull().mean() > pct]
    return lst

# %%
# columns with more than 50% of missing values
nan50 = nan_cols(df, 0.5)

# drop columns with more than 50% of missing values
df.drop(nan50, axis=1, inplace=True)

# %% [markdown]
# #### Removing data related to influenza as we are working specifically on this data

# %%
# how many column names with "influenza" in it
influenza = df.columns[df.columns.str.contains('influenza')].tolist()
influenza
# Out:
# ['icu_patients_confirmed_influenza',
#  'icu_patients_confirmed_influenza_coverage',
#  'previous_day_admission_influenza_confirmed',
#  'previous_day_admission_influenza_confirmed_coverage',
#  'previous_day_deaths_covid_and_influenza',
#  'previous_day_deaths_covid_and_influenza_coverage',
#  'previous_day_deaths_influenza',
#  'previous_day_deaths_influenza_coverage',
#  'total_patients_hospitalized_confirmed_influenza',
#  'total_patients_hospitalized_confirmed_influenza_and_covid',
#  'total_patients_hospitalized_confirmed_influenza_and_covid_coverage',
#  'total_patients_hospitalized_confirmed_influenza_coverage']

# %%
# drop influenza columns
df.drop(influenza, axis=1, inplace=True)

# %% [markdown]
# #### Remove the columns with "coverage"

# %%
# create a df wihtout columns that have "coverage" in it
df = df[df.columns[~df.columns.str.contains('coverage')]]

# %%
# print lal variables with correlation >0.8 but not equal to 1
corr = df.corr()
# pairs above 0.7
pairs = corr[corr > 0.95][corr != 1].stack().reset_index().sort_values(by=0, ascending=False)
pairs
# Out:
#                                                level_0  \
# 75                        total_staffed_adult_icu_beds
# 155              adult_icu_bed_utilization_denominator
# 40                     staffed_adult_icu_bed_occupancy
# 144                adult_icu_bed_utilization_numerator
# 160              adult_icu_bed_utilization_denominator
# ..                                                 ...
# 48          staffed_icu_adult_patients_confirmed_covid
# 98          percent_of_inpatients_with_covid_numerator
# 26        previous_day_admission_adult_covid_confirmed
# 53   total_adult_patients_hospitalized_confirmed_an...
# 43   staffed_icu_adult_patients_confirmed_and_suspe...
#
#                                                level_1         0
# 75               adult_icu_bed_utilization_denominator  0.999916
# 155                       total_staffed_adult_icu_beds  0.999916
# 40                 adult_icu_bed_utilization_numerator  0.999886
# 144                    staffed_adult_icu_bed_occupancy  0.999886
# 160        adult_icu_bed_covid_utilization_denominator  0.999836
# ..                                                 ...       ...
# 48          percent_of_inpatients_with_covid_numerator  0.950948
# 98        previous_day_admission_adult_covid_confirmed  0.950347
# 26          percent_of_inpatients_with_covid_numerator  0.950347
# 53   staffed_icu_adult_patients_confirmed_and_suspe...  0.950032
# 43   total_adult_patients_hospitalized_confirmed_an...  0.950032
#
# [182 rows x 3 columns]

# %%
# how many unique variables in pairs
pairs['level_0'].nunique()
# Out:
# 33

# %% [markdown]
# Should we maybe do some sort of Holistic Regression or whatnot to reduce the number of variables ? or do it manually ? <br>
# Do we really want to keep pediatrics ?

# %% [markdown]
# #### Remove "states" that are actually territories

# %%
# drop rows with number of points per state < 900
df = df.groupby('state').filter(lambda x: len(x) > 900)

#  how many states in df
df['state'].nunique()
# Out:
# 53

# %%
# remove VI, PR and AS from df
df = df[~df['state'].isin(['VI', 'PR', 'AS'])]

#  how many states in df
df['state'].nunique()
# Out:
# 51

# %%
df.shape
# Out:
# (50088, 68)

# %%
df.head()
# Out:
#   state       date  critical_staffing_shortage_today_yes  \
# 0    ME 2021-01-20                                     3
# 1    SD 2021-01-20                                     2
# 2    MS 2021-01-17                                    12
# 3    CT 2021-01-13                                     4
# 4    MT 2021-01-13                                    10
#
#    critical_staffing_shortage_today_no  \
# 0                                   28
# 1                                   60
# 2                                   95
# 3                                   35
# 4                                   56
#
#    critical_staffing_shortage_today_not_reported  \
# 0                                              8
# 1                                              3
# 2                                              2
# 3                                              1
# 4                                              1
#
#    critical_staffing_shortage_anticipated_within_week_yes  \
# 0                                                  2
# 1                                                  2
# 2                                                 16
# 3                                                  4
# 4                                                 11
#
#    critical_staffing_shortage_anticipated_within_week_no  \
# 0                                                 29
# 1                                                 60
# 2                                                 91
# 3                                                 35
# 4                                                 55
#
#    critical_staffing_shortage_anticipated_within_week_not_reported  \
# 0                                                  8
# 1                                                  3
# 2                                                  2
# 3                                                  1
# 4                                                  1
#
#    hospital_onset_covid  inpatient_beds  ...  \
# 0                   7.0          3246.0  ...
# 1                  34.0          2857.0  ...
# 2                  10.0          8692.0  ...
# 3                  31.0          8451.0  ...
# 4                  18.0          3220.0  ...
#
#    on_hand_supply_therapeutic_a_casirivimab_imdevimab_courses  \
# 0                                              174.0
# 1                                              519.0
# 2                                              356.0
# 3                                             1625.0
# 4                                             1645.0
#
#    on_hand_supply_therapeutic_b_bamlanivimab_courses  \
# 0                                              347.0
# 1                                              914.0
# 2                                             2668.0
# 3                                             3443.0
# 4                                              470.0
#
#    on_hand_supply_therapeutic_c_bamlanivimab_etesevimab_courses  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    previous_week_therapeutic_a_casirivimab_imdevimab_courses_used  \
# 0                                                1.0
# 1                                               22.0
# 2                                              100.0
# 3                                               10.0
# 4                                              130.0
#
#    previous_week_therapeutic_b_bamlanivimab_courses_used  \
# 0                                               54.0
# 1                                              244.0
# 2                                             1514.0
# 3                                              194.0
# 4                                              947.0
#
#    previous_week_therapeutic_c_bamlanivimab_etesevimab_courses_used  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    all_pediatric_inpatient_bed_occupied  all_pediatric_inpatient_beds  \
# 0                                 167.0                         220.0
# 1                                 297.0                         363.0
# 2                                 345.0                        2453.0
# 3                                 454.0                         685.0
# 4                                  71.0                         163.0
#
#    staffed_pediatric_icu_bed_occupancy  total_staffed_pediatric_icu_beds
# 0                                 47.0                              54.0
# 1                                 33.0                              83.0
# 2                                 78.0                             180.0
# 3                                196.0                             335.0
# 4                                 12.0                              40.0
#
# [5 rows x 68 columns]

# %% [markdown]
# ## Remove columns with still too many NaNs

# %%
# number of Nan values in each column as a dataframe
df.isna().sum().to_frame().sort_values(by=0, ascending=False).head(10)
# Out:
#                                                         0
# on_hand_supply_therapeutic_c_bamlanivimab_etese...  19640
# previous_week_therapeutic_c_bamlanivimab_etesev...  19623
# on_hand_supply_therapeutic_b_bamlanivimab_courses   15321
# previous_week_therapeutic_b_bamlanivimab_course...  15285
# on_hand_supply_therapeutic_a_casirivimab_imdevi...  15088
# previous_week_therapeutic_a_casirivimab_imdevim...  15087
# total_staffed_pediatric_icu_beds                     7768
# all_pediatric_inpatient_beds                         7764
# staffed_pediatric_icu_bed_occupancy                  7756
# all_pediatric_inpatient_bed_occupied                 7752

# %% [markdown]
# We can remove all the columns with therapeutic as they have more than 15,000 NaN

# %%
# print columns with "therapeutic" in column name
therapeutic = df.columns[df.columns.str.contains('therapeutic')].tolist()
therapeutic
# Out:
# ['on_hand_supply_therapeutic_a_casirivimab_imdevimab_courses',
#  'on_hand_supply_therapeutic_b_bamlanivimab_courses',
#  'on_hand_supply_therapeutic_c_bamlanivimab_etesevimab_courses',
#  'previous_week_therapeutic_a_casirivimab_imdevimab_courses_used',
#  'previous_week_therapeutic_b_bamlanivimab_courses_used',
#  'previous_week_therapeutic_c_bamlanivimab_etesevimab_courses_used']

# %%
# drop columns with "therapeutic" in column name
df.drop(therapeutic, axis=1, inplace=True)

# %%
# output df to csv
df.to_csv('covid_clean.csv', index=False)

# %% [markdown]
# ## Data imputation

# %%
# use KNN imputer to fill missing values
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)

# %%
# use KNN imputer to fill missing numeric values
df.iloc[:, 2:] = imputer.fit_transform(df.iloc[:, 2:])
# df = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
#  number of Nan values in the df
df.isna().sum().sum()
# Out:
# 0

# %%
# KNN imputer for string values
# df['state'] = df['state'].fillna(df['state'].mode()[0])

# %%
# output df to csv
df.to_csv('covid_clean_imputted.csv', index=False)

# %% [markdown]
# ### Lets build a correlation plot of the variables in our model

# %%
corrM = df.corr()
corrM.style.background_gradient(cmap='coolwarm',axis=None).set_precision(2)
# Out:
# <style type="text/css">
# #T_bf11b_row0_col0, #T_bf11b_row1_col1, #T_bf11b_row2_col2, #T_bf11b_row3_col3, #T_bf11b_row4_col4, #T_bf11b_row5_col5, #T_bf11b_row6_col6, #T_bf11b_row7_col7, #T_bf11b_row7_col24, #T_bf11b_row7_col30, #T_bf11b_row8_col8, #T_bf11b_row8_col23, #T_bf11b_row8_col27, #T_bf11b_row9_col9, #T_bf11b_row9_col26, #T_bf11b_row9_col29, #T_bf11b_row10_col10, #T_bf11b_row11_col11, #T_bf11b_row12_col12, #T_bf11b_row13_col13, #T_bf11b_row14_col14, #T_bf11b_row14_col35, #T_bf11b_row15_col15, #T_bf11b_row15_col32, #T_bf11b_row16_col16, #T_bf11b_row17_col17, #T_bf11b_row18_col18, #T_bf11b_row19_col19, #T_bf11b_row20_col20, #T_bf11b_row21_col21, #T_bf11b_row21_col33, #T_bf11b_row21_col36, #T_bf11b_row22_col22, #T_bf11b_row23_col8, #T_bf11b_row23_col23, #T_bf11b_row23_col27, #T_bf11b_row24_col7, #T_bf11b_row24_col24, #T_bf11b_row24_col30, #T_bf11b_row25_col25, #T_bf11b_row26_col9, #T_bf11b_row26_col26, #T_bf11b_row26_col29, #T_bf11b_row27_col8, #T_bf11b_row27_col23, #T_bf11b_row27_col27, #T_bf11b_row28_col28, #T_bf11b_row29_col9, #T_bf11b_row29_col26, #T_bf11b_row29_col29, #T_bf11b_row30_col7, #T_bf11b_row30_col24, #T_bf11b_row30_col30, #T_bf11b_row31_col31, #T_bf11b_row32_col15, #T_bf11b_row32_col32, #T_bf11b_row33_col21, #T_bf11b_row33_col33, #T_bf11b_row33_col36, #T_bf11b_row34_col34, #T_bf11b_row35_col14, #T_bf11b_row35_col35, #T_bf11b_row36_col21, #T_bf11b_row36_col33, #T_bf11b_row36_col36, #T_bf11b_row37_col37, #T_bf11b_row38_col38, #T_bf11b_row39_col39, #T_bf11b_row40_col40, #T_bf11b_row41_col41, #T_bf11b_row42_col42, #T_bf11b_row43_col43, #T_bf11b_row44_col44, #T_bf11b_row45_col45, #T_bf11b_row46_col46, #T_bf11b_row47_col47, #T_bf11b_row48_col48, #T_bf11b_row49_col49, #T_bf11b_row50_col50, #T_bf11b_row51_col51, #T_bf11b_row52_col52, #T_bf11b_row53_col53, #T_bf11b_row54_col54, #T_bf11b_row55_col55, #T_bf11b_row56_col56, #T_bf11b_row57_col57, #T_bf11b_row58_col58, #T_bf11b_row59_col59 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bf11b_row0_col1, #T_bf11b_row1_col0, #T_bf11b_row8_col18, #T_bf11b_row11_col16, #T_bf11b_row12_col26, #T_bf11b_row12_col29, #T_bf11b_row16_col11, #T_bf11b_row18_col8, #T_bf11b_row18_col27, #T_bf11b_row26_col12, #T_bf11b_row26_col51, #T_bf11b_row27_col18, #T_bf11b_row29_col12, #T_bf11b_row29_col51, #T_bf11b_row51_col26, #T_bf11b_row51_col29 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T
{
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_bf11b_row0_col10, #T_bf11b_row1_col15, #T_bf11b_row1_col17, #T_bf11b_row9_col58, #T_bf11b_row10_col0, #T_bf11b_row11_col20, #T_bf11b_row13_col48, #T_bf11b_row15_col1, #T_bf11b_row17_col1, #T_bf11b_row20_col11, #T_bf11b_row26_col57, #T_bf11b_row28_col42, #T_bf11b_row29_col57, #T_bf11b_row40_col58, #T_bf11b_row42_col28, #T_bf11b_row48_col13, #T_bf11b_row57_col26, #T_bf11b_row57_col29, #T_bf11b_row58_col9, #T_bf11b_row58_col40 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_bf11b_row0_col11, #T_bf11b_row1_col41, #T_bf11b_row3_col38, #T_bf11b_row4_col17, #T_bf11b_row6_col8, #T_bf11b_row6_col23, #T_bf11b_row6_col27, #T_bf11b_row6_col43, #T_bf11b_row8_col6, #T_bf11b_row11_col0, #T_bf11b_row15_col31, #T_bf11b_row15_col59, #T_bf11b_row16_col28, #T_bf11b_row16_col58, #T_bf11b_row17_col4, #T_bf11b_row19_col48, #T_bf11b_row23_col6, #T_bf11b_row27_col6, #T_bf11b_row28_col16, #T_bf11b_row31_col15, #T_bf11b_row32_col59, #T_bf11b_row38_col3, #T_bf11b_row39_col56, #T_bf11b_row39_col57, #T_bf11b_row39_col59, #T_bf11b_row41_col1, #T_bf11b_row43_col6, #T_bf11b_row48_col19, #T_bf11b_row56_col39, #T_bf11b_row57_col39, #T_bf11b_row58_col16, #T_bf11b_row59_col15, #T_bf11b_row59_col32, #T_bf11b_row59_col39 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_bf11b_row0_col12, #T_bf11b_row0_col13, #T_bf11b_row0_col34, #T_bf11b_row0_col55, #T_bf11b_row2_col47, #T_bf11b_row7_col54, #T_bf11b_row12_col0, #T_bf11b_row13_col0, #T_bf11b_row20_col34, #T_bf11b_row24_col54, #T_bf11b_row30_col54, #T_bf11b_row33_col55, #T_bf11b_row34_col0, #T_bf11b_row34_col20, #T_bf11b_row34_col40, #T_bf11b_row40_col34, #T_bf11b_row47_col2, #T_bf11b_row53_col55, #T_bf11b_row54_col7, #T_bf11b_row54_col24, #T_bf11b_row54_col30, #T_bf11b_row55_col0, #T_bf11b_row55_col33, #T_bf11b_row55_col53 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_bf11b_row0_col14, #T_bf11b_row0_col35, #T_bf11b_row0_col42, #T_bf11b_row0_col49, #T_bf11b_row3_col9, #T_bf11b_row4_col58, #T_bf11b_row9_col3, #T_bf11b_row13_col20, #T_bf11b_row14_col0, #T_bf11b_row17_col58, #T_bf11b_row20_col13, #T_bf11b_row20_col48, #T_bf11b_row35_col0, #T_bf11b_row38_col53, #T_bf11b_row42_col0, #T_bf11b_row44_col47, #T_bf11b_row46_col53, #T_bf11b_row47_col44, #T_bf11b_row48_col20, #T_bf11b_row49_col0, #T_bf11b_row53_col38, #T_bf11b_row53_col46, #T_bf11b_row58_col4, #T_bf11b_row58_col17 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_bf11b_row0_col15, #T_bf11b_row0_col32, #T_bf11b_row1_col49, #T_bf11b_row4_col49, #T_bf11b_row9_col47, #T_bf11b_row15_col0, #T_bf11b_row32_col0, #T_bf11b_row40_col48, #T_bf11b_row41_col52, #T_bf11b_row43_col53, #T_bf11b_row47_col9, #T_bf11b_row48_col40, #T_bf11b_row48_col59, #T_bf11b_row49_col1, #T_bf11b_row49_col4, #T_bf11b_row49_col58, #T_bf11b_row50_col59, #T_bf11b_row52_col41, #T_bf11b_row53_col43, #T_bf11b_row53_col58, #T_bf11b_row58_col49, #T_bf11b_row58_col53, #T_bf11b_row

# %%
# Fill diagonal and upper half with NaNs
mask = np.zeros_like(corrM, dtype=bool)
mask[np.triu_indices_from(mask)] = True
0c_row1_col41, #T_92b0c_row1_col42, #T_92b0c_row1_col43, #T_92b0c_row1_col44, #T_92b0c_row1_col45, #T_92b0c_row1_col46, #T_92b0c_row1_col47, #T_92b0c_row1_col48, #T_92b0c_row1_col49, #T_92b0c_row1_col50, #T_92b0c_row1_col51, #T_92b0c_row1_col52, #T_92b0c_row1_col53, #T_92b0c_row1_col54, #T_92b0c_row1_col55, #T_92b0c_row1_col56, #T_92b0c_row1_col57, #T_92b0c_row1_col58, #T_92b0c_row1_col59, #T_92b0c_row2_col2, #T_92b0c_row2_col3, #T_92b0c_row2_col4, #T_92b0c_row2_col5, #T_92b0c_row2_col6, #T_92b0c_row2_col7, #T_92b0c_row2_col8, #T_92b0c_row2_col9, #T_92b0c_row2_col10, #T_92b0c_row2_col11, #T_92b0c_row2_col12, #T_92b0c_row2_col13, #T_92b0c_row2_col14, #T_92b0c_row2_col15, #T_92b0c_row2_col16, #T_92b0c_row2_col17, #T_92b0c_row2_col18, #T_92b0c_row2_col19, #T_92b0c_row2_col20, #T_92b0c_row2_col21, #T_92b0c_row2_col22, #T_92b0c_row2_col23, #T_92b0c_row2_col24, #T_92b0c_row2_col25, #T_92b0c_row2_col26, #T_92b0c_row2_col27, #T_92b0c_row2_col28, #T_92b0c_row2_col29, #T_92b0c_row2_col30, #T_92b0c_row2_col31, #T_92b0c_row2_col32, #T_92b0c_row2_col33, #T_92b0c_row2_col34, #T_92b0c_row2_col35, #T_92b0c_row2_col36, #T_92b0c_row2_col37, #T_92b0c_row2_col38, #T_92b0c_row2_col39, #T_92b0c_row2_col40, #T_92b0c_row2_col41, #T_92b0c_row2_col42, #T_92b0c_row2_col43, #T_92b0c_row2_col44, #T_92b0c_row2_col45, #T_92b0c_row2_col46, #T_92b0c_row2_col47, #T_92b0c_row2_col48, #T_92b0c_row2_col49, #T_92b0c_row2_col50, #T_92b0c_row2_col51, #T_92b0c_row2_col52, #T_92b0c_row2_col53, #T_92b0c_row2_col54, #T_92b0c_row2_col55, #T_92b0c_row2_col56, #T_92b0c_row2_col57, #T_92b0c_row2_col58, #T_92b0c_row2_col59, #T_92b0c_row3_col3, #T_92b0c_row3_col4, #T_92b0c_row3_col5, #T_92b0c_row3_col6, #T_92b0c_row3_col7, #T_92b0c_row3_col8, #T_92b0c_row3_col9, #T_92b0c_row3_col10, #T_92b0c_row3_col11, #T_92b0c_row3_col12, #T_92b0c_row3_col13, #T_92b0c_row3_col14, #T_92b0c_row3_col15, #T_92b0c_row3_col16, #T_92b0c_row3_col17, #T ...

# %% [markdown]
# # Easter egg: gini impurity code for ML :)

# %%
#  gini impurity function with two probabilities
def gini(p1, p2):
    g = 1 - (p1**2 + p2**2)
    return g

# %%
p1 = 2/11
p2 = abs(1 - p1)

# gini impurity for p1 and p2 as a fraction 
g1 = gini(p1, p2)
g1
# Out:
# 0.2975206611570249

# %%
p1 = 9/15
p2 = abs(1 - p1)
# gini impurity for p1 and p2 as a fraction 
g2 = gini(p1, p2)
g2
# Out:
# 0.48

# %%
prop1 = 11/26
prop2 = abs(1 - prop1)

gt = prop1*g1 + prop2*g2
gt
# Out:
# 0.40279720279720277
